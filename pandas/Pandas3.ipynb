# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bipulshahi/Dataset/main/Big_Mart_Sales_Figure.csv')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.isna().sum()/len(df)
# Out:
# Item_Identifier              0.000000
# Item_Weight                  0.171653
# Item_Fat_Content             0.000000
# Item_Visibility              0.000000
# Item_Type                    0.000000
# Item_MRP                     0.000000
# Outlet_Identifier            0.000000
# Outlet_Establishment_Year    0.000000
# Outlet_Size                  0.282764
# Outlet_Location_Type         0.000000
# Outlet_Type                  0.000000
# Item_Outlet_Sales            0.000000
# dtype: float64

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
def fix_fat_content(fat_type):
  if fat_type in ['Low Fat', 'low fat', 'LF']:
    return 'low fat'
  else:
    return 'regular'

# %%
fix_fat_content('Regular')
# Out:
# 'regular'

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
#apply() -> used to apply a user defined function on each value of a data column

df['Item_Fat_Content'] = df['Item_Fat_Content'].apply(fix_fat_content)

# %%
df.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                2
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['low fat', 'regular'], dtype=object)

# %%
df['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
df['Item_Type'].value_counts()
# Out:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
df.head(3)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          low fat         0.016047        Dairy
# 1           DRC01         5.92          regular         0.019278  Soft Drinks
# 2           FDN15        17.50          low fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Item_Weight'].mean()
# Out:
# 12.857645184135976

# %%
#average Item weight of each type of fat content
df.groupby('Item_Fat_Content')['Item_Weight'].mean()
# Out:
# Item_Fat_Content
# low fat    12.937387
# regular    12.711654
# Name: Item_Weight, dtype: float64

# %%
#average item weight of each item type
df.groupby('Item_Type')['Item_Weight'].mean()
# Out:
# Item_Type
# Baking Goods             12.277108
# Breads                   11.346936
# Breakfast                12.768202
# Canned                   12.305705
# Dairy                    13.426069
# Frozen Foods             12.867061
# Fruits and Vegetables    13.224769
# Hard Drinks              11.400328
# Health and Hygiene       13.142314
# Household                13.384736
# Meat                     12.817344
# Others                   13.853285
# Seafood                  12.552843
# Snack Foods              12.987880
# Soft Drinks              11.847460
# Starchy Foods            13.690731
# Name: Item_Weight, dtype: float64

# %%
df.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          low fat         0.016047
# 1           DRC01         5.92          regular         0.019278
# 2           FDN15        17.50          low fat         0.016760
# 3           FDX07        19.20          regular         0.000000
# 4           NCD19         8.93          low fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.tail(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          low fat         0.056783
# 8519           FDS36        8.380          regular         0.046982
# 8520           NCJ29       10.600          low fat         0.035186
# 8521           FDN46        7.210          regular         0.145221
# 8522           DRG01       14.800          low fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
df.groupby('Item_Type')['Item_Weight'].transform('mean')
# Out:
# 0       13.426069
# 1       11.847460
# 2       12.817344
# 3       13.224769
# 4       13.384736
#           ...
# 8518    12.987880
# 8519    12.277108
# 8520    13.142314
# 8521    12.987880
# 8522    11.847460
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
df['Item_Weight'] = df['Item_Weight'].fillna(df.groupby('Item_Type')['Item_Weight'].transform('mean'))

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
df['Outlet_Size']
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3          NaN
# 4         High
#          ...
# 8518      High
# 8519       NaN
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
pd.crosstab(df['Outlet_Type'], df['Outlet_Size'])
# Out:
# Outlet_Size        High  Medium  Small
# Outlet_Type
# Grocery Store         0       0    528
# Supermarket Type1   932     930   1860
# Supermarket Type2     0     928      0
# Supermarket Type3     0     935      0

# %%
df['Outlet_Type'].value_counts()
# Out:
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64

# %%
pd.crosstab(df['Outlet_Location_Type'], df['Outlet_Size'])
# Out:
# Outlet_Size           High  Medium  Small
# Outlet_Location_Type
# Tier 1                   0     930   1458
# Tier 2                   0       0    930
# Tier 3                 932    1863      0

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# Outlet_Location_Type
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: count, dtype: int64

# %% [markdown]
# * we can fill the missing values of Outlet_size considering it is in Tier 1, Tier 2 or Tier 3

# %%
def fix_outlet_size(out_loc_type):
  if out_loc_type in ['Tier 1','Tier 2']:
    return 'Small'
  else:
    return 'High'

# %%
#apply this function on 'Outlet_Location_Type'

df['Outlet_Location_Type'].apply(fix_outlet_size)
# Out:
# 0       Small
# 1        High
# 2       Small
# 3        High
# 4        High
#         ...
# 8518     High
# 8519    Small
# 8520    Small
# 8521     High
# 8522    Small
# Name: Outlet_Location_Type, Length: 8523, dtype: object

# %%
df['Outlet_Size'] = df['Outlet_Size'].fillna(df['Outlet_Location_Type'].apply(fix_outlet_size))

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          low fat         0.016047
# 1           DRC01         5.92          regular         0.019278
# 2           FDN15        17.50          low fat         0.016760
# 3           FDX07        19.20          regular         0.000000
# 4           NCD19         8.93          low fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# **Assignment**
#   * Calculate coorelation between numerical columns & plot heat map
#   * Box-plot & Histogram plot on Item_Outlet_Sales
#   * Identify %ge outliers if it is there in sales

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          low fat         0.016047
# 1           DRC01         5.92          regular         0.019278
# 2           FDN15        17.50          low fat         0.016760
# 3           FDX07        19.20          regular         0.000000
# 4           NCD19         8.93          low fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df_number =  df.select_dtypes('number')

df_number.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.011620  0.025821
# Item_Visibility              -0.011620         1.000000 -0.001315
# Item_MRP                      0.025821        -0.001315  1.000000
# Outlet_Establishment_Year    -0.008376        -0.074834  0.005020
# Item_Outlet_Sales             0.012088        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.008376           0.012088
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
import seaborn as sns

sns.heatmap(df_number.corr(), annot=True , fmt = '.2f')
# Out:
# <Axes: >

# %%
#Box-plot & Histogram plot on Item_Outlet_Sales

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.boxplot(df['Item_Outlet_Sales'])

plt.subplot(1,2,2)
sns.histplot(df['Item_Outlet_Sales'])

plt.show()

# %%
#Box-plot & Histogram plot on Item_Outlet_Sales

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.boxplot(np.log(df['Item_Outlet_Sales']))

plt.subplot(1,2,2)
sns.histplot(np.log(df['Item_Outlet_Sales']))

plt.show()

# %%
#Outlier detection using box plot

q1 = np.log(df['Item_Outlet_Sales']).quantile(0.25)
q3 = np.log(df['Item_Outlet_Sales']).quantile(0.75)

iqr = q3 - q1

lower_limit = q1 - 1.5*iqr
upper_limit = q3 + 1.5*iqr

print(lower_limit, upper_limit)

print()

print((((np.log(df['Item_Outlet_Sales']) >= lower_limit) & (np.log(df['Item_Outlet_Sales']) <= upper_limit)).sum())/len(df))
# Out:
# 4.756960961558495 10.00914421762982
#
# 0.9795846532910947

# %%
#outlier detection using standard deviation

mean_sales = np.log(df['Item_Outlet_Sales']).mean()
std_sales = np.log(df['Item_Outlet_Sales']).std()

#Second standard deviation

lower_fence = mean_sales - 3*std_sales
upper_fence = mean_sales + 3*std_sales

print((((np.log(df['Item_Outlet_Sales']) >= lower_fence) & (np.log(df['Item_Outlet_Sales']) <= upper_fence)).sum())/len(df))
# Out:
# 0.9927255661152177

# %%
sns.histplot(np.log(df['Item_Outlet_Sales']))
plt.axvline(lower_limit, color='r')
plt.axvline(upper_limit, color='r')

plt.show()
